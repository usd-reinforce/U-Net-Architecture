# %%
import os
import numpy as np
import PIL.Image
import pandas as pd
import cv2
from models import UNet
from dataset import ISICDataset
from preprocessing import laplacian_hr, resize_image

# %%
input_path = 'dataset/training/input'
img_path = os.path.join(input_path, 'ISIC_00000102.jpg')
resized = resize_image(img_path)
img, dilated = laplacian_hr(resized, True)
# Out:
# [ WARN:0@3.217] global loadsave.cpp:278 findDecoder imread_('dataset/training/input/ISIC_00000102.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 input_path = 'dataset/training/input'
#       2 img_path = os.path.join(input_path, 'ISIC_00000102.jpg')
# ----> 3 resized = resize_image(img_path)
#       4 img, dilated = laplacian_hr(resized, True)
#
# File ~/G/skripsi/preprocessing/resize_image.py:6, in resize_image(image_path, target_size)
#       4 img = cv2.imread(image_path)
#       5 if img is None:
# ----> 6     raise ValueError("Gambar tidak ditemukan. Cek kembali path/lokasi file.")
#       7 resized_img = cv2.resize(img, target_size, interpolation=cv2.INTER_CUBIC)
#       8 return resized_img
#
# ValueError: Gambar tidak ditemukan. Cek kembali path/lokasi file.

# %%
# cv2.imshow("resized", resized)
# ori = cv2.imread(img_path)
# cv2.imshow("original", ori)
# cv2.imshow("image", img)
# cv2.imshow("dilated img", dilated)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
